# %% [markdown]
# # ASL MNIST — analiza datasetu
#
# Ten notebook sprawdza podstawowe właściwości zbioru danych: rozmiar train/test, rozkład klas oraz przykładowe obrazy znaków.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd

from configs.constants import TEST_CSV, TRAIN_CSV
from src.helpers import plot_class_distribution, plot_label_samples
from IPython.display import display

# %%
train_df = pd.read_csv(PROJECT_ROOT / TRAIN_CSV)
test_df = pd.read_csv(PROJECT_ROOT / TEST_CSV)

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)

train_df.head()
# Out:
# Train shape: (27455, 785)
# Test shape: (7172, 785)
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
# ...

# %% [markdown]
# ## Rozkład klas
#
# Sprawdzamy, czy klasy są w miarę równo reprezentowane w zbiorze treningowym.

# %%
display(plot_class_distribution(train_df, title="Rozkład klas w zbiorze treningowym"))

# %% [markdown]
# ## Przykładowe znaki
#
# Poniżej są po 3 przykłady z każdej klasy. Litera po lewej stronie oznacza klasę w danym wierszu.

# %%
display(plot_label_samples(
    train_df,
    samples_per_class=3,
    title="3 przykłady z każdej klasy",
))

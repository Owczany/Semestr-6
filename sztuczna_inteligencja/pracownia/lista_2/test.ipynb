# %%
s = set()
g = set()
g = {(0, 0), (2, 0)}

s.add((1, 1))
s.add((0, 0))
s.add((1, 1))

print(s.difference(g))
# Out:
# {(1, 1)}

# %%
D = {'a': 1, 'b': 2}

print(D.values())
# Out:
# dict_values([1, 2])
